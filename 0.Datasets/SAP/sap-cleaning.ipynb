# %%
import pandas as pd

data = pd.read_csv('../train_test_split/train.csv', encoding='utf-8')
data = data.iloc[:, 1:] # remove docid, qid columns
data
# Out:
#         qid   docid                                           question  \
# 0      7658  171072    Are RSUs ever taxed as long term capital gains?
# 1      4290  403701  Are there special exceptions to the rule that ...
# 2      9298  481203  Info about managment compansation schemes in p...
# 3      7058  416007    Using stop-loss as risk management: Is it safe?
# 4      6319  331722  Making a big purchase over $2500. I have the m...
# ...     ...     ...                                                ...
# 13652  7622  253369                          Best way to pay off debt?
# 13653  5665  303432  Where to Park Proceeds from House Sale for 2-5...
# 13654  2601  458907          Shorting: What if you can't find lenders?
# 13655  3622  502291  Why could rental costs for apartments/houses r...
# 13656  1104  553328          How do you declare an interest free loan?
#
#                                                   answer
# 0      I don't know the legal framework for RSUs, so ...
# 1      This is really an extended comment on the last...
# 2      Converting the comment from @MD-Tech into answ...
# 3      A stop-loss order becomes a market order when ...
# 4      There are a couple of things to consider here ...
# ...                                                  ...
# 13652  The key phrase in your post is that the option...
# 13653  As soon as you specify FDIC you immediately el...
# 13654  If you can't find anyone to lend you the share...
# 13655  Economically, you would say that purchased and...
# 13656  I am neither a lawyer nor a tax accountant, an...
#
# [13657 rows x 4 columns]

# %%
def check_2500_ch(row):
    if len(row) >= 2500:
        return True
    else:
        return False

def check_500_ch(row):
    if len(row) >= 500:
        return True
    else:
        return False

# %%
# run checkers
data['long_question'] = data['question'].apply(lambda x:check_500_ch(x))
data['long_answer'] = data['answer'].apply(lambda x:check_2500_ch(x))

# drop rows where question or answer is too long
data.drop(data[data['long_question'] == True].index, inplace=True)
data.drop(data[data['long_answer'] == True].index, inplace=True)
data.reset_index(inplace=True)
data = data.iloc[:, 1:5]

# clean for SAP conversational AI
data.drop_duplicates(subset='question', inplace=True) # remove duplicate question
data.reset_index(inplace=True)
data = data.iloc[:, 1:]
data
# Out:
#        qid   docid                                           question  \
# 0     7658  171072    Are RSUs ever taxed as long term capital gains?
# 1     9298  481203  Info about managment compansation schemes in p...
# 2     7058  416007    Using stop-loss as risk management: Is it safe?
# 3     6319  331722  Making a big purchase over $2500. I have the m...
# 4     1926  510888  Does a growing economy mean the economy is bec...
# ...    ...     ...                                                ...
# 5898  6743  437208  How to protect a Stock you still want to own f...
# 5899  3912   89662  As a US Permanent Resident, how much money I c...
# 5900   111   46092  Dual Citizen British/US and online business taxes
# 5901  1094   62047                     How to get a grip on finance?
# 5902  7622  253369                          Best way to pay off debt?
#
#                                                  answer
# 0     I don't know the legal framework for RSUs, so ...
# 1     Converting the comment from @MD-Tech into answ...
# 2     A stop-loss order becomes a market order when ...
# 3     There are a couple of things to consider here ...
# 4     It's a kook movie made by folks who combine co...
# ...                                                 ...
# 5898  Adding on to all the fine answers, you can con...
# 5899  I assume that you are a citizen of India, and ...
# 5900  I see no reason why a US ID would be mandatory...
# 5901  I think this question is perfectly on topic, a...
# 5902  The key phrase in your post is that the option...
#
# [5903 rows x 4 columns]

# %%
# export cleaned dataset for evaluation
data.to_csv('sap-qna-train-full-v2.csv', index=False, encoding='utf-8')

# %%
data_short = data.iloc[:, 2:] # remove qid and docid columns for training
data_short
# Out:
#                                                question  \
# 0       Are RSUs ever taxed as long term capital gains?
# 1     Info about managment compansation schemes in p...
# 2       Using stop-loss as risk management: Is it safe?
# 3     Making a big purchase over $2500. I have the m...
# 4     Does a growing economy mean the economy is bec...
# ...                                                 ...
# 5898  How to protect a Stock you still want to own f...
# 5899  As a US Permanent Resident, how much money I c...
# 5900  Dual Citizen British/US and online business taxes
# 5901                     How to get a grip on finance?
# 5902                          Best way to pay off debt?
#
#                                                  answer
# 0     I don't know the legal framework for RSUs, so ...
# 1     Converting the comment from @MD-Tech into answ...
# 2     A stop-loss order becomes a market order when ...
# 3     There are a couple of things to consider here ...
# 4     It's a kook movie made by folks who combine co...
# ...                                                 ...
# 5898  Adding on to all the fine answers, you can con...
# 5899  I assume that you are a citizen of India, and ...
# 5900  I see no reason why a US ID would be mandatory...
# 5901  I think this question is perfectly on topic, a...
# 5902  The key phrase in your post is that the option...
#
# [5903 rows x 2 columns]

# %%
# export cleaned dataset for training
data_short.to_csv('sap-qna-train-v2.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Generate training dataset for SAP CAI

# %%
import pandas as pd

data = pd.read_csv('../QnA.csv', encoding='utf-8')
data = data.iloc[:, 1:] # remove docid, qid columns
data
# Out:
#          qid   docid                                           question  \
# 0          0   18850  What is considered a business expense on a bus...
# 1          1   14255  Claiming business expenses for a business with...
# 2          2  308938  Transferring money from One business checking ...
# 3          3  296717  Having a separate bank account for business/in...
# 4          3  100764  Having a separate bank account for business/in...
# ...      ...     ...                                                ...
# 17067  11096  407726              Pensions, annuities, and “retirement”
# 17068  11097  131224  What does it mean to a life insurance policy h...
# 17069  11099  424427  Can capital loss in traditional IRA and Roth I...
# 17070  11099  150878  Can capital loss in traditional IRA and Roth I...
# 17071  11104  518310  Selling a stock for gain to offset other stock...
#
#                                                   answer
# 0      The IRS Guidance pertaining to the subject.  I...
# 1      Yes you can claim your business deductions if ...
# 2      You should have separate files for each of the...
# 3      Having a separate checking account for the bus...
# 4      You don't specify which country you are in, so...
# ...                                                  ...
# 17067  An annuity is a product. In simple terms, you ...
# 17068  A stock insurance company is structured like a...
# 17069  Edited in response to JoeTaxpayer's comment an...
# 17070  No, you cannot. If you withdraw everything fro...
# 17071  Long term gains are taxed at 15% maximum.  Los...
#
# [17072 rows x 4 columns]

# %%
def check_2500_ch(row):
    if len(row) >= 2500:
        return True
    else:
        return False

def check_500_ch(row):
    if len(row) >= 500:
        return True
    else:
        return False

# %%
data['long_question'] = data['question'].apply(lambda x:check_500_ch(x))
data['long_answer'] = data['answer'].apply(lambda x:check_2500_ch(x))
data
# Out:
#          qid   docid                                           question  \
# 0          0   18850  What is considered a business expense on a bus...
# 1          1   14255  Claiming business expenses for a business with...
# 2          2  308938  Transferring money from One business checking ...
# 3          3  296717  Having a separate bank account for business/in...
# 4          3  100764  Having a separate bank account for business/in...
# ...      ...     ...                                                ...
# 17067  11096  407726              Pensions, annuities, and “retirement”
# 17068  11097  131224  What does it mean to a life insurance policy h...
# 17069  11099  424427  Can capital loss in traditional IRA and Roth I...
# 17070  11099  150878  Can capital loss in traditional IRA and Roth I...
# 17071  11104  518310  Selling a stock for gain to offset other stock...
#
#                                                   answer  long_question  \
# 0      The IRS Guidance pertaining to the subject.  I...          False
# 1      Yes you can claim your business deductions if ...          False
# 2      You should have separate files for each of the...          False
# 3      Having a separate checking account for the bus...          False
# 4      You don't specify which country you are in, so...          False
# ...                                                  ...            ...
# 17067  An annuity is a product. In simple terms, you ...          False
# 17068  A stock insurance company is structured like a...          False
# 17069  Edited in response to JoeTaxpayer's comment an...          False
# 17070  No, you cannot. If you withdraw everything fro...          False
# 17071  Long term gains are taxed at 15% maximum.  Los...          False
#
#        long_answer
# 0             True
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 17067         True
# 17068         True
# 17069         True
# 17070        False
# 17071        False
#
# [17072 rows x 6 columns]

# %%
# drop rows where question or answer is too long
data.drop(data[data['long_question'] == True].index, inplace=True)
data.drop(data[data['long_answer'] == True].index, inplace=True)
data.reset_index(inplace=True)
data = data.iloc[:, 1:5]
data
# Out:
#          qid   docid                                           question  \
# 0          1   14255  Claiming business expenses for a business with...
# 1          2  308938  Transferring money from One business checking ...
# 2          3  296717  Having a separate bank account for business/in...
# 3          3  100764  Having a separate bank account for business/in...
# 4          3  314352  Having a separate bank account for business/in...
# ...      ...     ...                                                ...
# 15970  11096  132601              Pensions, annuities, and “retirement”
# 15971  11096  147730              Pensions, annuities, and “retirement”
# 15972  11096  522438              Pensions, annuities, and “retirement”
# 15973  11099  150878  Can capital loss in traditional IRA and Roth I...
# 15974  11104  518310  Selling a stock for gain to offset other stock...
#
#                                                   answer
# 0      Yes you can claim your business deductions if ...
# 1      You should have separate files for each of the...
# 2      Having a separate checking account for the bus...
# 3      You don't specify which country you are in, so...
# 4      If it makes your finances easier, why not? My ...
# ...                                                  ...
# 15970  There are broadly two kinds of pension: final ...
# 15971  Pension in this instance seems to mean pension...
# 15972  With an annuity, you invest directly into an a...
# 15973  No, you cannot. If you withdraw everything fro...
# 15974  Long term gains are taxed at 15% maximum.  Los...
#
# [15975 rows x 4 columns]

# %%
# clean for SAP conversational AI
data.drop_duplicates(subset='question', inplace=True) # remove duplicate question
data.reset_index(inplace=True)
data = data.iloc[:, 1:]
data
# Out:
#         qid   docid                                           question  \
# 0         1   14255  Claiming business expenses for a business with...
# 1         2  308938  Transferring money from One business checking ...
# 2         3  296717  Having a separate bank account for business/in...
# 3         4  196463  Business Expense - Car Insurance Deductible Fo...
# 4         5   69306                     Starting a new online business
# ...     ...     ...                                                ...
# 6464  11090   69696  Incorporating real-world parameters into simul...
# 6465  11092  374410  Is real (physical) money traded during online ...
# 6466  11096  132601              Pensions, annuities, and “retirement”
# 6467  11099  150878  Can capital loss in traditional IRA and Roth I...
# 6468  11104  518310  Selling a stock for gain to offset other stock...
#
#                                                  answer
# 0     Yes you can claim your business deductions if ...
# 1     You should have separate files for each of the...
# 2     Having a separate checking account for the bus...
# 3     As a general rule, you must choose between a m...
# 4     Most US states have rules that go something li...
# ...                                                 ...
# 6464  You said the decision will be made by EOD. If ...
# 6465  With Forex trading - physical currency is not ...
# 6466  There are broadly two kinds of pension: final ...
# 6467  No, you cannot. If you withdraw everything fro...
# 6468  Long term gains are taxed at 15% maximum.  Los...
#
# [6469 rows x 4 columns]

# %%
data_short = data.iloc[:, 2:] # remove qid and docid columns for training
data_short
# Out:
#                                                question  \
# 0     Claiming business expenses for a business with...
# 1     Transferring money from One business checking ...
# 2     Having a separate bank account for business/in...
# 3     Business Expense - Car Insurance Deductible Fo...
# 4                        Starting a new online business
# ...                                                 ...
# 6464  Incorporating real-world parameters into simul...
# 6465  Is real (physical) money traded during online ...
# 6466              Pensions, annuities, and “retirement”
# 6467  Can capital loss in traditional IRA and Roth I...
# 6468  Selling a stock for gain to offset other stock...
#
#                                                  answer
# 0     Yes you can claim your business deductions if ...
# 1     You should have separate files for each of the...
# 2     Having a separate checking account for the bus...
# 3     As a general rule, you must choose between a m...
# 4     Most US states have rules that go something li...
# ...                                                 ...
# 6464  You said the decision will be made by EOD. If ...
# 6465  With Forex trading - physical currency is not ...
# 6466  There are broadly two kinds of pension: final ...
# 6467  No, you cannot. If you withdraw everything fro...
# 6468  Long term gains are taxed at 15% maximum.  Los...
#
# [6469 rows x 2 columns]

# %%
# export cleaned dataset for evaluation
# data.to_csv('sap-qna-full-v2.csv', index=False, encoding='utf-8')

# %%
# export cleaned dataset for training
# data_short.to_csv('sap-qna-v2.csv', index=False, encoding='utf-8')
